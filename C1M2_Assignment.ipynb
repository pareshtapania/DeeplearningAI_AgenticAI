# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an assay write.
    write a detailed assay based on topic {topic}
    """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an crique for the assay writer.
    
    Based on the draft input {draft}, analyze this input, and provide the feedback
    on clarity, strengthen the arguments, and improe the writing style. 
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    you are an assay write.
    
    Refine the original draft assay " {original_draft} " based on the feedback 
    reflection "{reflection}"
    
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )
    
    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: Navigating the Digital Frontier: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In the contemporary digital age, social media platforms have become a ubiquitous part of everyday life, influencing public discourse, shaping opinions, and acting as conduits for information dissemination. These platforms, including giants like Facebook, Twitter, Instagram, and TikTok, have transformed the way individuals communicate and access information. However, the proliferation of social media has also raised significant concerns regarding privacy, misinformation, hate speech, and the concentration of power in the hands of a few tech companies. Consequently, the debate over whether social media platforms should be regulated by the government is both timely and crucial. This essay explores the multifaceted dimensions of this issue, examining the arguments for and against government regulation, considering the implications for freedom of speech, privacy, and innovation.
#
# Arguments for Government Regulation
#
# 1. **Curbing Misinformation and Hate Speech**: One of the primary arguments for government regulation of social media is the rampant spread of misinformation and hate speech. Platforms frequently prioritize engagement over accuracy, leading to the viral spread of false information. This can have dire consequences, from influencing election outcomes to inciting violence. Government regulation could enforce stricter content moderation policies and hold platforms accountable for harmful content.
#
# 2. **Protecting User Privacy**: Social media companies collect vast amounts of personal data from users, often with minimal transparency about how this data is used. Government regulation could enforce stricter data protection measures, safeguarding user privacy and ensuring that individuals have greater control over their personal information. Policies similar to the European Union's General Data Protection Regulation (GDPR) could be implemented to enhance user privacy rights.
#
# 3. **Breaking Monopolistic Practices**: A few dominant players control the social media landscape, raising concerns about monopolistic practices and stifling competition. Government intervention could promote fair competition by breaking up tech monopolies, thereby fostering innovation and preventing any single entity from wielding excessive influence over public discourse.
#
# 4. **Ensuring National Security**: Social media platforms have been exploited by foreign entities to interfere in domestic affairs, including elections. Government regulation could implement measures to combat such interference, thereby safeguarding national security and the integrity of democratic processes.
#
# Arguments Against Government Regulation
#
# 1. **Threat to Freedom of Speech**: Opponents of government regulation argue that it could infringe upon freedom of speech, a cornerstone of democratic societies. Government control over social media content could lead to censorship and the suppression of dissenting voices, stifling the open exchange of ideas that the internet was meant to facilitate.
#
# 2. **The Challenge of Implementation**: Regulating social media on a global scale presents significant logistical challenges. Different countries have varying legal standards and cultural norms, making it difficult to create a one-size-fits-all regulatory framework. This could lead to fragmented regulations that burden social media companies and confuse users.
#
# 3. **Innovation at Risk**: Overregulation could stifle innovation and hinder the growth of new social media platforms. Burdensome compliance requirements might deter startups and entrepreneurs, consolidating power further in the hands of existing tech giants.
#
# 4. **Technological Prowess**: Critics also point out that governments may lack the technological expertise to effectively regulate rapidly evolving digital platforms. Without a deep understanding of the intricacies of social media, regulations could be ineffectual or detrimental, failing to address the core issues while imposing unnecessary restrictions.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is a complex and contentious issue, intertwining concerns of free speech, privacy, innovation, and public safety. While there are compelling arguments on both sides, it is clear that a balanced approach is necessary. Any regulatory framework should aim to protect users from harm while preserving the core values of expression and innovation that define the internet. Rather than imposing blanket regulations, a collaborative effort between governments, social media companies, and civil society may yield more nuanced and effective solutions. As social media continues to evolve, ongoing dialogue and adaptive governance will be essential in navigating this new frontier, ensuring that it serves the public good without compromising its foundational freedoms.
#
# 🧠 Feedback:
#
# Below is a structured critique of your draft essay, organized by section. For each part you will find comments on clarity, suggestions to strengthen the arguments (with evidence or sharper focus), and notes on writing style.
#
# 1. Introduction
# Clarity
# • Your intro paints the landscape well, but it lacks a clear thesis statement. After describing the rise of social media, add a sentence such as: “This essay argues that a measured form of government regulation—one that protects privacy and curbs disinformation without stifling free speech or innovation—is essential.”
# • Define upfront what you mean by “regulation.” Are you focusing on legal liability, data-privacy rules, antitrust actions, or all of the above?
#
# Strengthening
# • Hook with a concrete example (e.g., the 2016 U.S. election interference or the Cambridge Analytica scandal) to illustrate why regulation has become urgent.
# • Preview your main criteria for evaluating regulation: free speech, privacy, competition, and security.
#
# Style
# • Use active verbs (“Social media have reshaped,” rather than “social media platforms have become”).
# • Vary sentence length: one short sentence after a long one can heighten impact.
# • Avoid repetition (“social media platforms” appears three times in the first two sentences—swap in “these networks,” “such sites,” etc.).
#
# 2. Arguments for Government Regulation
# 2.1 Curbing Misinformation and Hate Speech
# Clarity
# • Be explicit about the scale: cite a study (e.g., MIT’s finding on false news spreading 6× faster than truth) or a real-world incident (e.g., Myanmar violence fueled by Facebook posts).
#
# Strengthening
# • Explain how regulation might work in practice: requiring platforms to publish transparency reports, imposing fines under a “notice and takedown” regime, or mandating third-party fact–checking.
# • Anticipate a counterpoint: who decides what’s “misinformation”? Briefly note the need for independent oversight.
#
# Style
# • Open with a topic sentence: “Unchecked misinformation on social media poses real‐world risks—from public health dangers during a pandemic to violent unrest.”
#
# 2.2 Protecting User Privacy
# Clarity
# • Spell out key provisions of GDPR that you might borrow: the right to be forgotten, data-portability, privacy-by-design.
#
# Strengthening
# • Compare jurisdictions: show how the U.S. approach (sectoral, FTC enforcement) differs from the EU’s comprehensive GDPR—and what lessons can be learned.
# • Reference current proposals, such as America’s proposed Data Protection Act or California’s CCPA.
#
# Style
# • Quote a relevant statistic (“In 2020 alone, Facebook reported harvesting data on over 87 million users without consent,” etc.). It makes your argument more vivid.
#
# 2.3 Breaking Monopolistic Practices
# Clarity
# • Name the “Big Four” tech firms you have in mind so the reader understands the scope.
#
# Strengthening
# • Discuss ongoing antitrust actions (U.S. DOJ’s suit against Google, EU investigations into Facebook). What remedies are on the table?
# • Explain potential downsides of break-ups—then show why you believe the benefits outweigh the risks.
#
# Style
# • Use parallel structure when listing possible interventions: “divestitures, interoperability mandates, and strengthened merger review.”
#
# 2.4 Ensuring National Security
# Clarity
# • Clarify whether you mean foreign election meddling, terrorist recruitment, or both. These both fall under “national security” but call for different regulatory tools.
#
# Strengthening
# • Cite examples of state-sponsored disinformation (e.g., Russian “troll farms”).
# • Outline how regulated transparency (“Who’s behind this ad?” labels) can deter foreign actors.
#
# Style
# • Introduce a case study in one or two sentences to humanize your point.
#
# 3. Arguments Against Government Regulation
# 3.1 Threat to Freedom of Speech
# Clarity
# • Distinguish between private-sector moderation (companies setting their own rules) and government-imposed censorship. The risk you want to highlight is the latter.
#
# Strengthening
# • Reference landmark free-speech cases (e.g., Brandenburg v. Ohio in the U.S.) or constitutional safeguards.
# • Acknowledge that platforms already remove content under their terms of service—so “censorship” can also come from within.
#
# Style
# • Contrast with a keener example: one person’s “hate speech” might be another’s “legitimate political dissent.” That tension sharpens the stakes.
#
# 3.2 The Challenge of Implementation
# Clarity
# • Explain why a global internet makes national regulation hard. Do you foresee a patchwork of national laws or a coordinated multilateral framework?
#
# Strengthening
# • Point to existing fragmentation (e.g., China’s Great Firewall, Germany’s NetzDG) as evidence of how varied regulations can be.
# • Propose mechanisms for coordination: OECD guidelines, UN‐backed digital charters, etc.
#
# Style
# • Keep sentences tight and issue-focused. Avoid drifting into unrelated “burdensome regulation” rants.
#
# 3.3 Innovation at Risk
# Clarity
# • Define what kind of innovation you’re concerned about: new social platforms, niche communities, or data-driven ad-tech?
#
# Strengthening
# • Cite research on how compliance costs burden startups. Perhaps a European startup index showing a decline post-GDPR.
# • Offer the counter that regulations can be “scaled” or “phased in” so small firms get grace periods.
#
# Style
# • Frame it as a trade-off: “While regulation aims to protect users, it can unintentionally raise barriers for newcomers.”
#
# 3.4 Technological Prowess
# Clarity
# • Be specific about where governments fall short—staffing, expertise, or ability to update rules fast enough.
#
# Strengthening
# • Highlight successful private–public partnerships (e.g., the U.S. Election Integrity Partnership) as a model for bridging the expertise gap.
#
# Style
# • Avoid broad generalizations. Instead of “Governments lack tech savvy,” write “Few agencies have the real-time data‐analysis capacities that platforms use to tune their algorithms.”
#
# 4. Conclusion
# Clarity
# • Restate your refined thesis clearly: a balanced, multi-stakeholder approach.
# • Summarize two or three concrete recommendations: e.g., adopt GDPR-style data rules, establish an independent content-oversight board, and strengthen antitrust enforcement.
#
# Strengthening
# • End with a forward‐looking note: “As AI-driven platforms emerge, regulators and industry must co-evolve to protect democratic values without curbing digital progress.”
#
# Style
# • Keep it concise—three to four sentences. Avoid introducing new arguments.
#
# Overall Writing-Style Tips
# • Adopt a consistent voice. If you start formal, stay formal.
# • Use signposting transitions: “First,” “By contrast,” “Ultimately.”
# • Cut redundancy. If “government regulation” appears twice in one sentence, swap in “state oversight” or “public policy.”
# • Where possible, anchor abstract claims in data or real events. This lends credibility and engages the reader.
# • Aim for unity and coherence: each paragraph should support one clear point, and all points should tie back to your central thesis.
#
# By tightening your thesis, enriching each argument with concrete examples or data, and polishing your prose (active voice, varied sentence structures, precise terminology), you’ll boost clarity, persuasiveness, and readability. Good luck!
# ✍️ Revised:
#
# Title: Navigating the Digital Frontier: The Case for Measured Government Regulation of Social Media
#
# Introduction
#
# In today's digital age, social media platforms have redefined communication, heavily influencing public discourse and acting as conduits for information dissemination. Networks such as Facebook, Twitter, Instagram, and TikTok have reshaped how individuals interact and access information, but they also bring significant challenges related to privacy, misinformation, hate speech, and monopolistic practices. This essay argues that a measured form of government regulation—one that protects privacy and curbs disinformation without stifling free speech or innovation—is essential. By examining free speech, privacy, competition, and security considerations, this essay explores the complex debate on whether and how governments should oversee social media.
#
# Arguments for Government Regulation
#
# **Curbing Misinformation and Hate Speech**
# Unchecked misinformation on social media poses real-world risks—from public health dangers during a pandemic to violent unrest. The rapid spread of false information on platforms, often driven by algorithms prioritizing engagement over accuracy, is well-documented. For example, an MIT study found that false news spreads six times faster than truth. Government regulation could enforce stricter content moderation policies, such as requiring platforms to publish transparency reports, implementing "notice and takedown" regimes, or mandating third-party fact-checking, to hold platforms accountable for harmful content. Nevertheless, independent oversight would be critical to address challenges in defining "misinformation."
#
# **Protecting User Privacy**
# Social media companies often collect extensive personal data with little transparency. Borrowing elements from the European Union's General Data Protection Regulation (GDPR), such as the right to be forgotten, data portability, and privacy-by-design, government regulation could ensure users have greater control over their personal information. A comparative analysis of different jurisdictions highlights that while the U.S. relies on sectoral regulations with FTC enforcement, the comprehensive GDPR offers valuable lessons for enhancing user privacy rights. Over 87 million Facebook users had data harvested without consent in 2020, illustrating the urgency of robust privacy protection measures.
#
# **Breaking Monopolistic Practices**
# A small number of tech giants, often referred to as the "Big Four"—Google, Facebook, Amazon, and Apple—dominate the social media landscape, raising concerns about their monopolistic practices. Government intervention, such as divestitures, interoperability mandates, and strengthened merger review, could promote fair competition. Ongoing U.S. DOJ suits against Google and EU investigations into Facebook exemplify current efforts to address these issues. While breaking up tech companies might have potential downsides, promoting innovation and preventing excessive control over public discourse are compelling benefits.
#
# **Ensuring National Security**
# Social media platforms face threats from foreign interference, including state-sponsored disinformation campaigns like Russian "troll farms." Government regulation could enhance transparency measures, such as labeling political ads to disclose their origins, thus deterring foreign actors. Addressing national security involves balancing foreign election meddling and terrorist recruitment. Humanizing this point, case studies of state interventions demonstrate the importance of regulated transparency in safeguarding democratic processes.
#
# Arguments Against Government Regulation
#
# **Threat to Freedom of Speech**
# Regulation raises concerns about infringing upon freedom of speech, a foundational democratic principle. While private-sector moderation involves companies setting their own rules, government-imposed censorship poses a greater threat. The contrast between "hate speech" and "legitimate political dissent" delineates the delicate balance needed. Platforms already remove content under their terms of service, illustrating that censorship risks can emerge internally even without government intervention.
#
# **The Challenge of Implementation**
# Regulating a global internet presents logistical challenges, with varying legal standards and cultural norms making a unified regulatory framework difficult. Existing fragmentation, such as Germany’s NetzDG and China’s Great Firewall, highlights the potential for a patchwork of national laws rather than coordinated multilateral frameworks. Proposals for mechanisms like OECD guidelines and UN-backed digital charters could guide coordinated efforts in regulation implementation.
#
# **Innovation at Risk**
# Overregulation may hinder innovation, particularly for startups and new social media platforms. Compliance costs have burdened startups, as seen in European declines post-GDPR enactment. However, scaling or phasing in regulations could offer grace periods for smaller firms, balancing regulatory intentions with minimizing barriers for newcomers. Ultimately, while regulation aims to protect users, it should not unintentionally stymie digital innovation.
#
# **Technological Prowess**
# Governments often lack the technological expertise to effectively regulate evolving social media platforms. This challenge involves staffing, expertise, and the ability to update regulations swiftly. Successful private-public partnerships, such as the U.S. Election Integrity Partnership, could model future cooperation to bridge the expertise gap and develop effective oversight mechanisms without overly restrictive regulations.
#
# Conclusion
#
# The question of regulating social media involves a complex interplay of free speech, privacy, innovation, and national security concerns. A balanced approach is necessary, with regulatory frameworks protecting users while preserving the values of expression and innovation intrinsic to the internet. As AI-driven platforms emerge, adaptable governance through the ongoing collaboration of governments, social media companies, and civil society will be crucial. By considering GDPR-style data rules, independent content-oversight boards, and strengthened antitrust enforcement, we can ensure social media serves the public good without compromising foundational freedoms.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: Should Social Media Platforms Be Regulated by the Government?
#
# Introduction
#
# In the contemporary digital age, social media platforms have become a ubiquitous part of everyday life, influencing public discourse, shaping opinions, and acting as conduits for information dissemination. These platforms, including giants like Facebook, Twitter, Instagram, and TikTok, have transformed the way individuals communicate and access information. However, the proliferation of social media has also raised significant concerns regarding privacy, misinformation, hate speech, and the concentration of power in the hands of a few tech companies. Consequently, the debate over whether social media platforms should be regulated by the government is both timely and crucial. This essay explores the multifaceted dimensions of this issue, examining the arguments for and against government regulation, considering the implications for freedom of speech, privacy, and innovation.
#
# Arguments for Government Regulation
#
# 1. **Curbing Misinformation and Hate Speech**: One of the primary arguments for government regulation of social media is the rampant spread of misinformation and hate speech. Platforms frequently prioritize engagement over accuracy, leading to the viral spread of false information. This can have dire consequences, from influencing election outcomes to inciting violence. Government regulation could enforce stricter content moderation policies and hold platforms accountable for harmful content.
#
# 2. **Protecting User Privacy**: Social media companies collect vast amounts of personal data from users, often with minimal transparency about how this data is used. Government regulation could enforce stricter data protection measures, safeguarding user privacy and ensuring that individuals have greater control over their personal information. Policies similar to the European Union's General Data Protection Regulation (GDPR) could be implemented to enhance user privacy rights.
#
# 3. **Breaking Monopolistic Practices**: A few dominant players control the social media landscape, raising concerns about monopolistic practices and stifling competition. Government intervention could promote fair competition by breaking up tech monopolies, thereby fostering innovation and preventing any single entity from wielding excessive influence over public discourse.
#
# 4. **Ensuring National Security**: Social media platforms have been exploited by foreign entities to interfere in domestic affairs, including elections. Government regulation could implement measures to combat such interference, thereby safeguarding national security and the integrity of democratic processes.
#
# Arguments Against Government Regulation
#
# 1. **Threat to Freedom of Speech**: Opponents of government regulation argue that it could infringe upon freedom of speech, a cornerstone of democratic societies. Government control over social media content could lead to censorship and the suppression of dissenting voices, stifling the open exchange of ideas that the internet was meant to facilitate.
#
# 2. **The Challenge of Implementation**: Regulating social media on a global scale presents significant logistical challenges. Different countries have varying legal standards and cultural norms, making it difficult to create a one-size-fits-all regulatory framework. This could lead to fragmented regulations that burden social media companies and confuse users.
#
# 3. **Innovation at Risk**: Overregulation could stifle innovation and hinder the growth of new social media platforms. Burdensome compliance requirements might deter startups and entrepreneurs, consolidating power further in the hands of existing tech giants.
#
# 4. **Technological Prowess**: Critics also point out that governments may lack the technological expertise to effectively regulate rapidly evolving digital platforms. Without a deep understanding of the intricacies of social media, regulations could be ineffectual or detrimental, failing to address the core issues while imposing unnecessary restrictions.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is a complex and contentious issue, intertwining concerns of free speech, privacy, innovation, and public safety. While there are compelling arguments on both sides, it is clear that a balanced approach is necessary. Any regulatory framework should aim to protect users from harm while preserving the core values of expression and innovation that define the internet. Rather than imposing blanket regulations, a collaborative effort between governments, social media companies, and civil society may yield more nuanced and effective solutions. As social media continues to evolve, ongoing dialogue and adaptive governance will be essential in navigating this new frontier, ensuring that it serves the public good without compromising its foundational freedoms.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Below is a structured critique of your draft essay, organized by section. For each part you will find comments on clarity, suggestions to strengthen the arguments (with evidence or sharper focus), and notes on writing style.
#
# 1. Introduction
# Clarity
# • Your intro paints the landscape well, but it lacks a clear thesis statement. After describing the rise of social media, add a sentence such as: “This essay argues that a measured form of government regulation—one that protects privacy and curbs disinformation without stifling free speech or innovation—is essential.”
# • Define upfront what you mean by “regulation.” Are you focusing on legal liability, data-privacy rules, antitrust actions, or all of the above?
#
# Strengthening
# • Hook with a concrete example (e.g., the 2016 U.S. election interference or the Cambridge Analytica scandal) to illustrate why regulation has become urgent.
# • Preview your main criteria for evaluating regulation: free speech, privacy, competition, and security.
#
# Style
# • Use active verbs (“Social media have reshaped,” rather than “social media platforms have become”).
# • Vary sentence length: one short sentence after a long one can heighten impact.
# • Avoid repetition (“social media platforms” appears three times in the first two sentences—swap in “these networks,” “such sites,” etc.).
#
# 2. Arguments for Government Regulation
# 2.1 Curbing Misinformation and Hate Speech
# Clarity
# • Be explicit about the scale: cite a study (e.g., MIT’s finding on false news spreading 6× faster than truth) or a real-world incident (e.g., Myanmar violence fueled by Facebook posts).
#
# Strengthening
# • Explain how regulation might work in practice: requiring platforms to publish transparency reports, imposing fines under a “notice and takedown” regime, or mandating third-party fact–checking.
# • Anticipate a counterpoint: who decides what’s “misinformation”? Briefly note the need for independent oversight.
#
# Style
# • Open with a topic sentence: “Unchecked misinformation on social media poses real‐world risks—from public health dangers during a pandemic to violent unrest.”
#
# 2.2 Protecting User Privacy
# Clarity
# • Spell out key provisions of GDPR that you might borrow: the right to be forgotten, data-portability, privacy-by-design.
#
# Strengthening
# • Compare jurisdictions: show how the U.S. approach (sectoral, FTC enforcement) differs from the EU’s comprehensive GDPR—and what lessons can be learned.
# • Reference current proposals, such as America’s proposed Data Protection Act or California’s CCPA.
#
# Style
# • Quote a relevant statistic (“In 2020 alone, Facebook reported harvesting data on over 87 million users without consent,” etc.). It makes your argument more vivid.
#
# 2.3 Breaking Monopolistic Practices
# Clarity
# • Name the “Big Four” tech firms you have in mind so the reader understands the scope.
#
# Strengthening
# • Discuss ongoing antitrust actions (U.S. DOJ’s suit against Google, EU investigations into Facebook). What remedies are on the table?
# • Explain potential downsides of break-ups—then show why you believe the benefits outweigh the risks.
#
# Style
# • Use parallel structure when listing possible interventions: “divestitures, interoperability mandates, and strengthened merger review.”
#
# 2.4 Ensuring National Security
# Clarity
# • Clarify whether you mean foreign election meddling, terrorist recruitment, or both. These both fall under “national security” but call for different regulatory tools.
#
# Strengthening
# • Cite examples of state-sponsored disinformation (e.g., Russian “troll farms”).
# • Outline how regulated transparency (“Who’s behind this ad?” labels) can deter foreign actors.
#
# Style
# • Introduce a case study in one or two sentences to humanize your point.
#
# 3. Arguments Against Government Regulation
# 3.1 Threat to Freedom of Speech
# Clarity
# • Distinguish between private-sector moderation (companies setting their own rules) and government-imposed censorship. The risk you want to highlight is the latter.
#
# Strengthening
# • Reference landmark free-speech cases (e.g., Brandenburg v. Ohio in the U.S.) or constitutional safeguards.
# • Acknowledge that platforms already remove content under their terms of service—so “censorship” can also come from within.
#
# Style
# • Contrast with a keener example: one person’s “hate speech” might be another’s “legitimate political dissent.” That tension sharpens the stakes.
#
# 3.2 The Challenge of Implementation
# Clarity
# • Explain why a global internet makes national regulation hard. Do you foresee a patchwork of national laws or a coordinated multilateral framework?
#
# Strengthening
# • Point to existing fragmentation (e.g., China’s Great Firewall, Germany’s NetzDG) as evidence of how varied regulations can be.
# • Propose mechanisms for coordination: OECD guidelines, UN‐backed digital charters, etc.
#
# Style
# • Keep sentences tight and issue-focused. Avoid drifting into unrelated “burdensome regulation” rants.
#
# 3.3 Innovation at Risk
# Clarity
# • Define what kind of innovation you’re concerned about: new social platforms, niche communities, or data-driven ad-tech?
#
# Strengthening
# • Cite research on how compliance costs burden startups. Perhaps a European startup index showing a decline post-GDPR.
# • Offer the counter that regulations can be “scaled” or “phased in” so small firms get grace periods.
#
# Style
# • Frame it as a trade-off: “While regulation aims to protect users, it can unintentionally raise barriers for newcomers.”
#
# 3.4 Technological Prowess
# Clarity
# • Be specific about where governments fall short—staffing, expertise, or ability to update rules fast enough.
#
# Strengthening
# • Highlight successful private–public partnerships (e.g., the U.S. Election Integrity Partnership) as a model for bridging the expertise gap.
#
# Style
# • Avoid broad generalizations. Instead of “Governments lack tech savvy,” write “Few agencies have the real-time data‐analysis capacities that platforms use to tune their algorithms.”
#
# 4. Conclusion
# Clarity
# • Restate your refined thesis clearly: a balanced, multi-stakeholder approach.
# • Summarize two or three concrete recommendations: e.g., adopt GDPR-style data rules, establish an independent content-oversight board, and strengthen antitrust enforcement.
#
# Strengthening
# • End with a forward‐looking note: “As AI-driven platforms emerge, regulators and industry must co-evolve to protect democratic values without curbing digital progress.”
#
# Style
# • Keep it concise—three to four sentences. Avoid introducing new arguments.
#
# Overall Writing-Style Tips
# • Adopt a consistent voice. If you start formal, stay formal.
# • Use signposting transitions: “First,” “By contrast,” “Ultimately.”
# • Cut redundancy. If “government regulation” appears twice in one sentence, swap in “state oversight” or “public policy.”
# • Where possible, anchor abstract claims in data or real events. This lends credibility and engages the reader.
# • Aim for unity and coherence: each paragraph should support one clear point, and all points should tie back to your central thesis.
#
# By tightening your thesis, enriching each argument with concrete examples or data, and polishing your prose (active voice, varied sentence structures, precise terminology), you’ll boost clarity, persuasiveness, and readability. Good luck!</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: Navigating the Digital Frontier: The Case for Measured Government Regulation of Social Media
#
# Introduction
#
# In today's digital age, social media platforms have redefined communication, heavily influencing public discourse and acting as conduits for information dissemination. Networks such as Facebook, Twitter, Instagram, and TikTok have reshaped how individuals interact and access information, but they also bring significant challenges related to privacy, misinformation, hate speech, and monopolistic practices. This essay argues that a measured form of government regulation—one that protects privacy and curbs disinformation without stifling free speech or innovation—is essential. By examining free speech, privacy, competition, and security considerations, this essay explores the complex debate on whether and how governments should oversee social media.
#
# Arguments for Government Regulation
#
# **Curbing Misinformation and Hate Speech**
# Unchecked misinformation on social media poses real-world risks—from public health dangers during a pandemic to violent unrest. The rapid spread of false information on platforms, often driven by algorithms prioritizing engagement over accuracy, is well-documented. For example, an MIT study found that false news spreads six times faster than truth. Government regulation could enforce stricter content moderation policies, such as requiring platforms to publish transparency reports, implementing "notice and takedown" regimes, or mandating third-party fact-checking, to hold platforms accountable for harmful content. Nevertheless, independent oversight would be critical to address challenges in defining "misinformation."
#
# **Protecting User Privacy**
# Social media companies often collect extensive personal data with little transparency. Borrowing elements from the European Union's General Data Protection Regulation (GDPR), such as the right to be forgotten, data portability, and privacy-by-design, government regulation could ensure users have greater control over their personal information. A comparative analysis of different jurisdictions highlights that while the U.S. relies on sectoral regulations with FTC enforcement, the comprehensive GDPR offers valuable lessons for enhancing user privacy rights. Over 87 million Facebook users had data harvested without consent in 2020, illustrating the urgency of robust privacy protection measures.
#
# **Breaking Monopolistic Practices**
# A small number of tech giants, often referred to as the "Big Four"—Google, Facebook, Amazon, and Apple—dominate the social media landscape, raising concerns about their monopolistic practices. Government intervention, such as divestitures, interoperability mandates, and strengthened merger review, could promote fair competition. Ongoing U.S. DOJ suits against Google and EU investigations into Facebook exemplify current efforts to address these issues. While breaking up tech companies might have potential downsides, promoting innovation and preventing excessive control over public discourse are compelling benefits.
#
# **Ensuring National Security**
# Social media platforms face threats from foreign interference, including state-sponsored disinformation campaigns like Russian "troll farms." Government regulation could enhance transparency measures, such as labeling political ads to disclose their origins, thus deterring foreign actors. Addressing national security involves balancing foreign election meddling and terrorist recruitment. Humanizing this point, case studies of state interventions demonstrate the importance of regulated transparency in safeguarding democratic processes.
#
# Arguments Against Government Regulation
#
# **Threat to Freedom of Speech**
# Regulation raises concerns about infringing upon freedom of speech, a foundational democratic principle. While private-sector moderation involves companies setting their own rules, government-imposed censorship poses a greater threat. The contrast between "hate speech" and "legitimate political dissent" delineates the delicate balance needed. Platforms already remove content under their terms of service, illustrating that censorship risks can emerge internally even without government intervention.
#
# **The Challenge of Implementation**
# Regulating a global internet presents logistical challenges, with varying legal standards and cultural norms making a unified regulatory framework difficult. Existing fragmentation, such as Germany’s NetzDG and China’s Great Firewall, highlights the potential for a patchwork of national laws rather than coordinated multilateral frameworks. Proposals for mechanisms like OECD guidelines and UN-backed digital charters could guide coordinated efforts in regulation implementation.
#
# **Innovation at Risk**
# Overregulation may hinder innovation, particularly for startups and new social media platforms. Compliance costs have burdened startups, as seen in European declines post-GDPR enactment. However, scaling or phasing in regulations could offer grace periods for smaller firms, balancing regulatory intentions with minimizing barriers for newcomers. Ultimately, while regulation aims to protect users, it should not unintentionally stymie digital innovation.
#
# **Technological Prowess**
# Governments often lack the technological expertise to effectively regulate evolving social media platforms. This challenge involves staffing, expertise, and the ability to update regulations swiftly. Successful private-public partnerships, such as the U.S. Election Integrity Partnership, could model future cooperation to bridge the expertise gap and develop effective oversight mechanisms without overly restrictive regulations.
#
# Conclusion
#
# The question of regulating social media involves a complex interplay of free speech, privacy, innovation, and national security concerns. A balanced approach is necessary, with regulatory frameworks protecting users while preserving the values of expression and innovation intrinsic to the internet. As AI-driven platforms emerge, adaptable governance through the ongoing collaboration of governments, social media companies, and civil society will be crucial. By considering GDPR-style data rules, independent content-oversight boards, and strengthened antitrust enforcement, we can ensure social media serves the public good without compromising foundational freedoms.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
